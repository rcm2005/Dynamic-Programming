# %%
import pandas as pd
import numpy as np

# %%
import

# %%
dados1 = pd.read_csv("dados1.csv")
dados2 = pd.read_csv("dados2.csv")

# %%
dados2
# Out:
#        Unnamed: 0   ano     bloco  talhao  corte  tch_bloco
# 0               0  2021  604P0311       5      4      70.75
# 1               1  2021  111P1186      10      5      26.47
# 2               2  2021  116P1611       6     18      95.64
# 3               3  2021  116P1626       2     18     110.97
# 4               4  2021  134P1520       2      3      59.20
# ...           ...   ...       ...     ...    ...        ...
# 20015       20015  2022  605P0301      10      5      56.29
# 20016       20016  2022  220P2046       1      4      63.26
# 20017       20017  2022  226P2678       1      5      38.27
# 20018       20018  2022  225P2864       1      3      48.27
# 20019       20019  2022  225P2564      10      6      24.59
#
# [20020 rows x 6 columns]

# %%
display(dados1.columns)
display(dados2.columns)
# Out:
# Index(['Unnamed: 0', 'ano', 'bloco', 'ndvi', 'area', 'cdambiente'], dtype='object')
# Index(['Unnamed: 0', 'ano', 'bloco', 'talhao', 'corte', 'tch_bloco'], dtype='object')

# %%
base = pd.merge(dados2,dados1, on=["ano","bloco"])

# %%
base
# Out:
#         Unnamed: 0_x   ano     bloco  talhao  corte  tch_bloco  Unnamed: 0_y  \
# 0                  0  2021  604P0311       5      4      70.75             0
# 1                  0  2021  604P0311       5      4      70.75           225
# 2                  0  2021  604P0311       5      4      70.75          1073
# 3                  0  2021  604P0311       5      4      70.75          1154
# 4                  0  2021  604P0311       5      4      70.75          2481
# ...              ...   ...       ...     ...    ...        ...           ...
# 212881         19957  2022  238P3846       1      3      36.13         19957
# 212882         19977  2022  414P0042       1      4      70.47         19977
# 212883         19990  2022  601P0336       1      7      51.38         19990
# 212884         19991  2022  110F0041       1      5      65.16         19991
# 212885         20016  2022  220P2046       1      4      63.26         20016
#
#             ndvi   area cdambiente
# ...

# %%
##### mostre qual a media, medianda, min e maximo do nvdi por bloco
print("Media: ", np.mean(nvdi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 ##### mostre qual a media, medianda, min e maximo do nvdi por bloco
# ----> 2 print("Media: ", np.mean(nvdi))
#
# NameError: name 'np' is not defined

# %%
##### mostre qual a médai, medaiana, min e máximo nvdi por ambiente
##### mostre qual a médai, medaiana, min e máximo nvdi por corte
##### mostre qual a área total do canavial
##### mostre qual a área total do cancavial por bloco, mostre qual a área total do canavial por ambiente
##### mostre qual a área total do canavial por corte
